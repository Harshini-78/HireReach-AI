# %%
import os
from dotenv import load_dotenv
from langchain_groq import ChatGroq

load_dotenv()

llm = ChatGroq(
    temperature=0,
    groq_api_key=os.getenv("GROQ_API_KEY"),
    model_name="llama-3.3-70b-versatile"
)

response = llm.invoke(
    "Explain Artificial Intelligence in simple words"
)

print(response.content)
# Out:
# **What is Artificial Intelligence (AI)?**
#
# Artificial Intelligence is a way to make machines, like computers, think and learn like humans. It's like creating a robot that can understand, reason, and act on its own.
#
# **How does AI work?**
#
# Imagine you're teaching a child to recognize different objects, like cats and dogs. You show them many pictures, and they start to understand what makes a cat a cat and a dog a dog. AI works in a similar way:
#
# 1. **Learning**: AI systems are trained on large amounts of data, like pictures, words, or sounds.
# 2. **Pattern recognition**: The AI system looks for patterns in the data, like what makes a cat a cat.
# 3. **Decision-making**: The AI system uses the patterns it's learned to make decisions, like "this is a cat" or "this is a dog".
#
# **Types of AI:**
#
# 1. **Narrow AI**: Designed to perform a specific task, like recognizing faces or playing chess.
# 2. **General AI**: Aims to be as smart as a human, able to learn and apply knowledge across many areas.
# 3. **Super AI**: Even more advanced, with capabilities beyond human intelligence.
#
# **Examples of AI in everyday life:**
#
# 1. Virtual assistants, like Siri or Alexa
# 2. Image recognition, like Facebook's face tagging
# 3. Self-driving cars
# 4. Personalized recommendations, like Netflix or Amazon
#
# **In simple words**, Artificial Intelligence is a way to create machines that can think, learn, and act like humans, making our lives easier and more convenient.

# %%
import os
from langchain_community.document_loaders import WebBaseLoader

# Set user agent
os.environ["USER_AGENT"] = "MyLangChainBot/1.0"

loader = WebBaseLoader("https://jobs.nike.com/job/R-33460")

page_data = loader.load().pop().page_content

print(page_data)
# Out:
# Nike Careers
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to main content
# Open Virtual Assistant
#
#
#
#
#
#
#
#
#
#
# Home
#
#
# Career Areas
#
#
# Total Rewards
#
#
# Life@Nike
#
#
# Purpose
#
#
#
#
#
#
#
#
#
#
# Language
#
#
#
#
#
# Select a Language
#
#   Deutsch
#   English
#   Español (España)
#   Español (América Latina)
#   Français
#   Italiano
#   Nederlands
#   Polski
#   Tiếng Việt
#   Türkçe
#   简体中文
#   繁體中文
#   עִברִית
#   한국어
#   日本語
#
#
#
#
#
#
#
#
# Careers
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Close Menu
#
#
#
#
#
#
#
# Careers
#
#
#
#
#
#
# Chat
#
#
#
#
#
#
#                                 Home
#
#
#
#
#                                 Career Areas
#
#
#
#
#                                 Total Rewards
#
#
#
#
#                                 Life@Nike
#
#
#
#
#                                 Purpose
#
#
#
#
#
#
#
#
#
#
#
# Jordan Careers
#
#
#
#
#
#
#
# Converse Careers
#
#
#
#
#
#
#
#
#
#
# Language
#
#
#
#
#
#
#
#
#
#
#
# Menu
#
#
#
# Return to Previous Menu
#
#
#
# Select a Language
#
#   Deutsch
#   English
#   Español (España)
#   Español (América Latina)
#   Français
#   Italiano
#   Nederlands
#   Polski
#   Tiếng Việt
#   Türkçe
#   简体中文
#   繁體中文
#   עִברִית
#   한국어
#   日本語
#
#
#
#
#
#
#
#
#
#
#
#
#                 Your browser doesn't support HTML5 video tag.
#
#
#
#
#
#
#
#
#
#
# Play Full Video
#
#
#
# WHAT MOVES YOUMOVES OUR WORLD
#
#
#
#
#
#
#
# Pause Video
#
#
#
# Play Video
#
#
#
#
#
#
# Play 'How We Do It' video
#
#
#
#
# Play 'Victory Mode' video'
#
#
#
#
# Play 'Craft the Future' video
#
#
#
#
#
#
#
#
#
#
#
# Be In the Know
#
#
#
#
#
#
#
#
#
#
# Retail at NIKE, Inc.
# Learn More
#
#
#
#
#
#
#
#
#
#
# The Nike Internship Experience
# Learn More
#
#
#
#
#
#
#
#
#
#
# AI/ML Roles for Innovators
# Learn More
#
#
#
#
#
#
#
#
#
#
# Peek Into Our World
# Learn More
#
#
#
#
#
#
#
#
#
#
# NikeUNITED's Commitment
# Learn More
#
#
#
#
#
#
#
#
#
#
#
#
#
# IF YOU HAVE A BODY, YOU ARE AN ATHLETE.*
#
#
#
# These words drive who we are and what we believe in – a better future for ourselves, our communities and our athletes. We strive to bring inspiration and innovation to every athlete in the world, including our teammates.
#
#
#
#
#
#
#
#
# More Than Love of the Brand
# WHAT MOVES US
#
#
#
#
#
#
#
# Serve Athletes
#
#
#
# We believe in the power of sport. Taking ownership of our shared responsibility to action the voice of all athletes, we push ourselves and each other, turning ambition into achievement.
#
#
#
#
#
#
#
#
#
#
#
#
#
# Expand Serve Athletes Section
#
#
#
#
#
#
#
# Create the Future of Sport
#
#
#
# We understand every idea must meet a need and move people closer to their goals. That's why we're not afraid to fail - because innovation depends on risk.
#
#
#
#
#
#
#
#
#
#
#
#
#
# Expand Create the Future of Sport section
#
#
#
#
#
#
#
# Be On the Offense Always
#
#
#
# Agility is our edge. We put the consumer first by setting the pace, acting decisively and driving change to meet their
#                                             needs.
#
#
#
#
#
#
#
#
#
#
#
#
#
# Expand Be On the Offense Always section
#
#
#
#
#
#
#
# Do the Right Thing
#
#
#
# We value our unique opportunity to put ethics into action on the journey to level the playing field for all. This requires accountability, meaning we consistently make calls and own the results.
#
#
#
#
#
#
#
#
#
#
#
#
#
# Expand Do the Right Thing section
#
#
#
#
#
#
#
# Win as a Team
#
#
#
# We are strong together. Creating an environment where deep connections champion collaboration, it is expected that each player not only contributes to our collective wins but celebrates them.
#
#
#
#
#
#
#
#
#
#
#
#
#
# Expand Win as a Team section
#
#
#
#
#
#
#
#
#
#
#
#
# Go to Previous Slide
#
#
#
#
#
# Go to Next Slide
#
#
#
#
#
#
#
#
#
#
#
#
# Reinforcing Our Position
# CULTURE IN ACTION
# There is a sense of pride that comes from representing an iconic brand and shaping its future. Here, we treat
#                             every day
#                             as a new opportunity to push boundaries, ask tough questions and share whole-hearted convictions. We are a
#                             team – united
#                             by the belief that anything is possible.
# Learn More About Culture
#
#
#
#
#
#
#
# Elevating Your Well-Being
# FROM THE INSIDE OUT
# Rest and recovery are critical for you to be able to deliver at peak performance. You can count on us to walk
#                         the talk,
#                         providing resources and time that help keep life balanced and yourself fueled for any challenge. Compassion
#                         and
#                         flexibility enhance the supportive nature of our community.
# Learn More About Benefits
#
#
#
#
#
#
#
# Lacing Up for the Greater Good
# PURPOSE AT PLAY
# Moving the world forward through sport is no small feat. Together, we take steps to drive change by putting
#                             social
#                             impact and planet protection first. This shared passion for doing what's right fuels the NIKE, Inc. legacy
#                             and drives us
#                             forward.
# Learn
#                             More
#
#
#
#
#
#
# One Team. Iconic Brands.
# BEYOND THE SWOOSH
#
#
#
#
#
#
# Converse
# Bringing together those independent enough not to follow, we are catalyzing the collective power of people who see their differences as strengths. Converse is a creative team channeling ambition, expertise, and self-expression to drive innovation.
# Learn More About Converse
#
#
#
#
#
# Jordan
# Extending beyond sports into culture and fashion, Jordan Brand is bound by a commitment to serve a community representative of Michael himself. Those who make up this team thrive in an entrepreneurial environment, where creative problem-solving is leveraged to drive innovation.
#
#
#
#
#
#
# Search Jordan Careers
#
#
#
#
#
#
# Explore Careers
#
#
#
#
#
#
#
#
#
# Search Retail Careers
#
#
#
#
#
#
#
#
#
#
# Search Distribution Careers
#
#
#
#
#
#
#
#
#
#
# Search Manufacturing Careers
#
#
#
#
#
#
#
#
#
#
# Search Corporate Careers
#
#
#
#
#
#
#
#
#
#
# Search Open Internships
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# SEARCH CAREERS
#
#
#
#
#
# Close Modal
#
#
#
#
#
#
#
#                                     Apply Filters
#
#
#                                     Clear Filters
#
#
#
#
#
#
# All
#                                                 Careers
#
#
#
# Retail
#
#
# Distribution
#
#
# Manufacturing
#
#
# Corporate
#
#
# Internships
#
#
#
#
#
#
# Keyword SearchLocation SearchUse your locationUse your locationSearch
#
#
# Filters
#
#
#
#
# Filter ResultsCareer AreasAdvanced Innovation3Business Operations9Communications2Data2Design38Facilities & Real Estate4Finance & Accounting9General Counsel1Human Resources3Position TypeFull Time646Part Time240Is RemoteNo939Yes2BrandCONVERSE82JORDAN16NIKE843cf_employee_typeFixed Term Contract (Fixed Term)193Intern (Fixed Term)11Regular538Seasonal (Fixed Term) (Seasonal)180Temp Casual (Fixed Term)18Temp Trainee (Trainee)1cf_job_categoryCorporate235Distribution1Manufacturing3Retail702Clear Filter
#
#
#
#
#
#
#  Join The Talent Community
#
#
#
#
#
# Contract Jobs - USA Only*
#
#
#
#
#
#
#
#
#
#
#
#
# Edit Filters
#
#
#
#
#
#
#
#
#
# Kaufmann/-frau im Einzelhandel (Ausbildung) - 37.5H - Metzingen (w/m/d)R-81196Job LocationMetzingen, Baden-Wurttemberg, GermanyRetail StoresView JobRetail Associate, SEAS - Nike Thornton (0-40 hours/week)R-783483Job LocationThornton, Colorado, United StatesRetail StoresView JobAthlete 16PT (대전)R-84057Job LocationDaejeon, Daejeon, South KoreaRetail StoresView JobNike Operational Teamleiter (Lead) (w/m/d) – 38.5 (h) – NFS ParndorfR-82525Job LocationParndorf, Burgenland, AustriaRetail StoresView JobCoach Stockroom I Gerente de Almacén - NFS MX TijuanaR-83888Job LocationTijuana, Baja California, MexicoRetail StoresView JobAssistant Store Manager - Nike Aurora, OHR-83372Job LocationAurora, Ohio, United StatesRetail StoresView JobAthlete IIR-56644Job LocationGuangzhou, Guangdong, ChinaRetail StoresView JobDepartment Manager - Full Time - Nike PireosR-82651Job LocationAthens, Achaia, GreeceRetail StoresView JobRetail Associate, SEAS - Nike Pismo Beach (0-40 hours/week)R-783358Job LocationPismo Beach, California, United StatesRetail StoresView JobSenior Materials Designer CTM - ConverseR-80918Job LocationShanghai, Shanghai, ChinaProduct Creation, Development & ManagementView Job
# Go to first pageGo to previous page12345678910Go to next pageGo to last page1020
#
#
#
#
#
#
#
#
#
#
#
# Close
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Home
#
#
# About Us
#
#
# Contact
#
#
# Talent Community
#
#
# Terms
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                     Nike Applicant Privacy Policy
#
#
#
#
#
#
# We offer a number of accommodations to complete our interview process including screen readers, sign language interpreters,
#                 accessible and single location for in-person interviews, closed captioning, and other reasonable modifications as
#                 needed.
#
#
# If you discover, as you navigate our application process, that you need assistance or an accommodation due to a
#                 disability, please contact us at +1 503-671-4156 and include your full name, best way to reach you, and the
#                 accommodation you request to assist with the application process.
# For more information, please refer to Equal Employment
#                         Opportunity is The Law.
#
#
#
# ©  Nike, Inc. All Rights Reserved
#
#
#
#
#
#
#
#
#
#
#
#
#
# Careers
#
#
#
#
#
#
#
#
# Chat
# Chat with our AI Assistant

# %%
from langchain_core.prompts import PromptTemplate

prompt_extract = PromptTemplate.from_template(
        """
        ### SCRAPED TEXT FROM WEBSITE:
        {page_data}
        ### INSTRUCTION:
        The scraped text is from the career's page of a website.
        Your job is to extract the job postings and return them in JSON format containing the 
        following keys: `role`, `experience`, `skills` and `description`.
        Only return the valid JSON.
        ### VALID JSON (NO PREAMBLE):    
        """
)

chain_extract = prompt_extract | llm 
res = chain_extract.invoke(input={'page_data':page_data})
type(res.content)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 17
#       3 prompt_extract = PromptTemplate.from_template(
#       4         """
#       5         ### SCRAPED TEXT FROM WEBSITE:
#    (...)
#      13         """
#      14 )
#      16 chain_extract = prompt_extract | llm
# ---> 17 res = chain_extract.invoke(input={'page_data':page_data})
#      18 type(res.content)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\langchain_core\runnables\base.py:2854, in invoke(self, input, config, **kwargs)
#    2846             raise ValueError(msg)
#    2848     return RunnableConfigurableFields(default=self, fields=kwargs)
#    2850 def configurable_alternatives(
#    2851     self,
#    2852     which: ConfigurableField,
#    2853     *,
# -> 2854     default_key: str = "default",
#    2855     prefix_keys: bool = False,
#    2856     **kwargs: Runnable[Input, Output] | Callable[[], Runnable[Input, Output]],
#    2857 ) -> RunnableSerializable[Input, Output]:
#    2858     """Configure alternatives for `Runnable` objects that can be set at runtime.
#    2859
#    2860     Args:
#    (...)
#    2895         ```
#    2896     """
#    2897     # Import locally to prevent circular import
#
# ModuleNotFoundError: No module named 'langchain_core.beta'

# %%
# !pip uninstall -y langchain langchain-core langchain-community langchain-groq
# Out:
# Found existing installation: langchain 0.2.16
# Uninstalling langchain-0.2.16:
#   Successfully uninstalled langchain-0.2.16
# Found existing installation: langchain-core 1.4.0
# Uninstalling langchain-core-1.4.0:
#   Successfully uninstalled langchain-core-1.4.0
# Found existing installation: langchain-community 0.4.1
# Uninstalling langchain-community-0.4.1:
#   Successfully uninstalled langchain-community-0.4.1
# Found existing installation: langchain-groq 0.1.9
# Uninstalling langchain-groq-0.1.9:
#   Successfully uninstalled langchain-groq-0.1.9

# %%
# !pip install langchain==0.2.16
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting langchain==0.2.16
#   Using cached langchain-0.2.16-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\programdata\anaconda3\lib\site-packages (from langchain==0.2.16) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\programdata\anaconda3\lib\site-packages (from langchain==0.2.16) (2.0.34)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\programdata\anaconda3\lib\site-packages (from langchain==0.2.16) (3.10.5)
# Collecting langchain-core<0.3.0,>=0.2.38 (from langchain==0.2.16)
#   Using cached langchain_core-0.2.43-py3-none-any.whl.metadata (6.2 kB)
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain==0.2.16)
#   Using cached langchain_text_splitters-0.2.4-py3-none-any.whl.metadata (2.3 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain==0.2.16)
#   Using cached langsmith-0.1.147-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\programdata\anaconda3\lib\site-packages (from langchain==0.2.16) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in c:\programdata\anaconda3\lib\site-packages (from langchain==0.2.16) (2.8.2)
# Requirement already satisfied: requests<3,>=2 in c:\users\harshini\appdata\roaming\python\python312\site-packages (from langchain==0.2.16) (2.34.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\programdata\anaconda3\lib\site-packages (from langchain==0.2.16) (8.2.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.16) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.16) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.16) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.16) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.16) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.16) (1.11.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<0.3.0,>=0.2.38->langchain==0.2.16) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<0.3.0,>=0.2.38->langchain==0.2.16) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\harshini\appdata\roaming\python\python312\site-packages (from langchain-core<0.3.0,>=0.2.38->langchain==0.2.16) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.2.16) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\harshini\appdata\roaming\python\python312\site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.2.16) (3.11.9)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.2.16) (1.0.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3,>=1->langchain==0.2.16) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3,>=1->langchain==0.2.16) (2.20.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2->langchain==0.2.16) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2->langchain==0.2.16) (3.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2->langchain==0.2.16) (2.2.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2->langchain==0.2.16) (2025.4.26)
# Requirement already satisfied: greenlet!=0.4.17 in c:\programdata\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain==0.2.16) (3.0.1)
# Requirement already satisfied: anyio in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.2.16) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.2.16) (1.0.2)
# Requirement already satisfied: sniffio in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.2.16) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\programdata\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.2.16) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\programdata\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.38->langchain==0.2.16) (2.1)
# Using cached langchain-0.2.16-py3-none-any.whl (1.0 MB)
# Using cached langchain_core-0.2.43-py3-none-any.whl (397 kB)
# Using cached langchain_text_splitters-0.2.4-py3-none-any.whl (25 kB)
# Using cached langsmith-0.1.147-py3-none-any.whl (311 kB)
# Installing collected packages: langsmith, langchain-core, langchain-text-splitters, langchain
#   Attempting uninstall: langsmith
#     Found existing installation: langsmith 0.8.5
#     Uninstalling langsmith-0.8.5:
#       Successfully uninstalled langsmith-0.8.5
#   Attempting uninstall: langchain-text-splitters
#     Found existing installation: langchain-text-splitters 1.1.2
#     Uninstalling langchain-text-splitters-1.1.2:
#       Successfully uninstalled langchain-text-splitters-1.1.2
# Successfully installed langchain-0.2.16 langchain-core-0.2.43 langchain-text-splitters-0.2.4 langsmith-0.1.147
#   WARNING: The script langsmith.exe is installed in 'C:\Users\Harshini\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script langchain-server.exe is installed in 'C:\Users\Harshini\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-classic 1.0.7 requires langchain-core<2.0.0,>=1.3.3, but you have langchain-core 0.2.43 which is incompatible.
# langchain-classic 1.0.7 requires langchain-text-splitters<2.0.0,>=1.1.2, but you have langchain-text-splitters 0.2.4 which is incompatible.
# langgraph 1.2.0 requires langchain-core<2,>=1.4.0, but you have langchain-core 0.2.43 which is incompatible.
# langgraph-prebuilt 1.1.0 requires langchain-core>=1.3.1, but you have langchain-core 0.2.43 which is incompatible.

# %%
# !pip install langchain-core==0.2.38
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting langchain-core==0.2.38
#   Downloading langchain_core-0.2.38-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\programdata\anaconda3\lib\site-packages (from langchain-core==0.2.38) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\programdata\anaconda3\lib\site-packages (from langchain-core==0.2.38) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in c:\users\harshini\appdata\roaming\python\python312\site-packages (from langchain-core==0.2.38) (0.1.147)
# Requirement already satisfied: packaging<25,>=23.2 in c:\programdata\anaconda3\lib\site-packages (from langchain-core==0.2.38) (24.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\programdata\anaconda3\lib\site-packages (from langchain-core==0.2.38) (2.8.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core==0.2.38) (8.2.3)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\harshini\appdata\roaming\python\python312\site-packages (from langchain-core==0.2.38) (4.12.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\programdata\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core==0.2.38) (2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core==0.2.38) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\harshini\appdata\roaming\python\python312\site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core==0.2.38) (3.11.9)
# Requirement already satisfied: requests<3,>=2 in c:\users\harshini\appdata\roaming\python\python312\site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core==0.2.38) (2.34.2)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core==0.2.38) (1.0.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core==0.2.38) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core==0.2.38) (2.20.1)
# Requirement already satisfied: anyio in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core==0.2.38) (4.2.0)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core==0.2.38) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core==0.2.38) (1.0.2)
# Requirement already satisfied: idna in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core==0.2.38) (3.7)
# Requirement already satisfied: sniffio in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core==0.2.38) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\programdata\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core==0.2.38) (0.14.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core==0.2.38) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core==0.2.38) (2.2.3)
# Downloading langchain_core-0.2.38-py3-none-any.whl (396 kB)
# Installing collected packages: langchain-core
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.2.43
#     Uninstalling langchain-core-0.2.43:
#       Successfully uninstalled langchain-core-0.2.43
# Successfully installed langchain-core-0.2.38
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-classic 1.0.7 requires langchain-core<2.0.0,>=1.3.3, but you have langchain-core 0.2.38 which is incompatible.
# langchain-classic 1.0.7 requires langchain-text-splitters<2.0.0,>=1.1.2, but you have langchain-text-splitters 0.2.4 which is incompatible.
# langgraph 1.2.0 requires langchain-core<2,>=1.4.0, but you have langchain-core 0.2.38 which is incompatible.
# langgraph-prebuilt 1.1.0 requires langchain-core>=1.3.1, but you have langchain-core 0.2.38 which is incompatible.

# %%
# !pip install langchain-community==0.2.16
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting langchain-community==0.2.16
#   Downloading langchain_community-0.2.16-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\programdata\anaconda3\lib\site-packages (from langchain-community==0.2.16) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\programdata\anaconda3\lib\site-packages (from langchain-community==0.2.16) (2.0.34)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\programdata\anaconda3\lib\site-packages (from langchain-community==0.2.16) (3.10.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\harshini\appdata\roaming\python\python312\site-packages (from langchain-community==0.2.16) (0.6.7)
# Requirement already satisfied: langchain<0.3.0,>=0.2.16 in c:\users\harshini\appdata\roaming\python\python312\site-packages (from langchain-community==0.2.16) (0.2.16)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.38 in c:\users\harshini\appdata\roaming\python\python312\site-packages (from langchain-community==0.2.16) (0.2.38)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in c:\users\harshini\appdata\roaming\python\python312\site-packages (from langchain-community==0.2.16) (0.1.147)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-community==0.2.16) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in c:\users\harshini\appdata\roaming\python\python312\site-packages (from langchain-community==0.2.16) (2.34.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-community==0.2.16) (8.2.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.2.16) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.2.16) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.2.16) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.2.16) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.2.16) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.2.16) (1.11.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\harshini\appdata\roaming\python\python312\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.16) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\harshini\appdata\roaming\python\python312\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.16) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\harshini\appdata\roaming\python\python312\site-packages (from langchain<0.3.0,>=0.2.16->langchain-community==0.2.16) (0.2.4)
# Requirement already satisfied: pydantic<3,>=1 in c:\programdata\anaconda3\lib\site-packages (from langchain<0.3.0,>=0.2.16->langchain-community==0.2.16) (2.8.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<0.3.0,>=0.2.38->langchain-community==0.2.16) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<0.3.0,>=0.2.38->langchain-community==0.2.16) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\harshini\appdata\roaming\python\python312\site-packages (from langchain-core<0.3.0,>=0.2.38->langchain-community==0.2.16) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community==0.2.16) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\harshini\appdata\roaming\python\python312\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community==0.2.16) (3.11.9)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community==0.2.16) (1.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community==0.2.16) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community==0.2.16) (3.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community==0.2.16) (2.2.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community==0.2.16) (2025.4.26)
# Requirement already satisfied: greenlet!=0.4.17 in c:\programdata\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community==0.2.16) (3.0.1)
# Requirement already satisfied: anyio in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community==0.2.16) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community==0.2.16) (1.0.2)
# Requirement already satisfied: sniffio in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community==0.2.16) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\programdata\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community==0.2.16) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\programdata\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.38->langchain-community==0.2.16) (2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.16->langchain-community==0.2.16) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.16->langchain-community==0.2.16) (2.20.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\programdata\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.16) (1.0.0)
# Downloading langchain_community-0.2.16-py3-none-any.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB 1.9 MB/s eta 0:00:01
#    -------- ------------------------------- 0.5/2.3 MB 1.9 MB/s eta 0:00:01
#    ------------- -------------------------- 0.8/2.3 MB 1.2 MB/s eta 0:00:02
#    ---------------------- ----------------- 1.3/2.3 MB 1.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.3/2.3 MB 1.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.3/2.3 MB 1.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.3/2.3 MB 1.3 MB/s eta 0:00:01
#    -------------------------- ------------- 1.6/2.3 MB 883.2 kB/s eta 0:00:01
#    -------------------------- ------------- 1.6/2.3 MB 883.2 kB/s eta 0:00:01
#    ----------------------------------- ---- 2.1/2.3 MB 883.1 kB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 941.3 kB/s eta 0:00:00
# Installing collected packages: langchain-community
# Successfully installed langchain-community-0.2.16

# %%
# !pip install langchain-groq==0.1.9
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting langchain-groq==0.1.9
#   Using cached langchain_groq-0.1.9-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: groq<1,>=0.4.1 in c:\users\harshini\appdata\roaming\python\python312\site-packages (from langchain-groq==0.1.9) (0.37.1)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.26 in c:\users\harshini\appdata\roaming\python\python312\site-packages (from langchain-groq==0.1.9) (0.2.38)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\programdata\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq==0.1.9) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\programdata\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq==0.1.9) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq==0.1.9) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\programdata\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq==0.1.9) (2.8.2)
# Requirement already satisfied: sniffio in c:\programdata\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq==0.1.9) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\users\harshini\appdata\roaming\python\python312\site-packages (from groq<1,>=0.4.1->langchain-groq==0.1.9) (4.12.2)
# Requirement already satisfied: PyYAML>=5.3 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<0.3.0,>=0.2.26->langchain-groq==0.1.9) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<0.3.0,>=0.2.26->langchain-groq==0.1.9) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in c:\users\harshini\appdata\roaming\python\python312\site-packages (from langchain-core<0.3.0,>=0.2.26->langchain-groq==0.1.9) (0.1.147)
# Requirement already satisfied: packaging<25,>=23.2 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<0.3.0,>=0.2.26->langchain-groq==0.1.9) (24.1)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<0.3.0,>=0.2.26->langchain-groq==0.1.9) (8.2.3)
# Requirement already satisfied: idna>=2.8 in c:\programdata\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain-groq==0.1.9) (3.7)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq==0.1.9) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq==0.1.9) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\programdata\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq==0.1.9) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\programdata\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.26->langchain-groq==0.1.9) (2.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\harshini\appdata\roaming\python\python312\site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.26->langchain-groq==0.1.9) (3.11.9)
# Requirement already satisfied: requests<3,>=2 in c:\users\harshini\appdata\roaming\python\python312\site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.26->langchain-groq==0.1.9) (2.34.2)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.26->langchain-groq==0.1.9) (1.0.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq==0.1.9) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq==0.1.9) (2.20.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.26->langchain-groq==0.1.9) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.26->langchain-groq==0.1.9) (2.2.3)
# Using cached langchain_groq-0.1.9-py3-none-any.whl (14 kB)
# Installing collected packages: langchain-groq
# Successfully installed langchain-groq-0.1.9

# %%
from langchain_core.prompts import PromptTemplate

prompt_extract = PromptTemplate.from_template(
        """
        ### SCRAPED TEXT FROM WEBSITE:
        {page_data}
        ### INSTRUCTION:
        The scraped text is from the career's page of a website.
        Your job is to extract the job postings and return them in JSON format containing the 
        following keys: `role`, `experience`, `skills` and `description`.
        Only return the valid JSON.
        ### VALID JSON (NO PREAMBLE):    
        """
)

chain_extract = prompt_extract | llm 
res = chain_extract.invoke(input={'page_data':page_data})
type(res.content)
# Out:
# str

# %%
from langchain_core.output_parsers import JsonOutputParser

json_parser = JsonOutputParser()
json_res = json_parser.parse(res.content)
json_res
# Out:
# [{'role': 'Kaufmann/-frau im Einzelhandel (Ausbildung)',
#   'experience': '0-40 hours/week',
#   'skills': '',
#   'description': '37.5H - Metzingen (w/m/d)'},
#  {'role': 'Retail Associate, SEAS',
#   'experience': '0-40 hours/week',
#   'skills': '',
#   'description': 'Nike Thornton'},
#  {'role': 'Athlete 16PT',
#   'experience': '',
#   'skills': '',
#   'description': '(대전)'},
#  {'role': 'Nike Operational Teamleiter (Lead)',
#   'experience': '',
#   'skills': '',
#   'description': '– 38.5 (h) – NFS Parndorf'},
#  {'role': 'Coach Stockroom I Gerente de Almacén',
#   'experience': '',
#   'skills': '',
#   'description': '- NFS MX Tijuana'},
#  {'role': 'Assistant Store Manager',
#   'experience': 'Full Time',
#   'skills': '',
#   'description': '- Nike Aurora, OH'},
#  {'role': 'Athlete II', 'experience': '', 'skills': '', 'description': ''},
#  {'role': 'Department Manager',
#   'experience': 'Full Time',
#   'skills': '',
#   'description': '- Nike Pireos'},
#  {'role': 'Retail Associate, SEAS',
#   'experience': '0-40 hours/week',
#   'skills': '',
#   'description': '- Nike Pismo Beach'},
#  {'role': 'Senior Materials Designer CTM',
#   'experience': '',
#   'skills': '',
#   'description': '- Converse'}]

# %%
type(json_res)
# Out:
# list

# %%
import pandas as pd

df = pd.read_csv("my_portfolio.csv")
df
# Out:
#                                Techstack  \
# 0                React, Node.js, MongoDB
# 1               Angular,.NET, SQL Server
# 2      Vue.js, Ruby on Rails, PostgreSQL
# 3                  Python, Django, MySQL
# 4              Java, Spring Boot, Oracle
# 5             Flutter, Firebase, GraphQL
# 6                  WordPress, PHP, MySQL
# 7                    Magento, PHP, MySQL
# 8         React Native, Node.js, MongoDB
# 9                  iOS, Swift, Core Data
# 10       Android, Java, Room Persistence
# 11             Kotlin, Android, Firebase
# 12       Android TV, Kotlin, Android NDK
# 13                     iOS, Swift, ARKit
# 14        Cross-platform, Xamarin, Azure
# 15          Backend, Kotlin, Spring Boot
# 16         Frontend, TypeScript, Angular
# 17    Full-stack, JavaScript, Express.js
# 18  Machine Learning, Python, TensorFlow
# 19               DevOps, Jenkins, Docker
#
#                                                 Links
# 0                 https://example.com/react-portfolio
# 1               https://example.com/angular-portfolio
# 2                   https://example.com/vue-portfolio
# 3                https://example.com/python-portfolio
# 4                  https://example.com/java-portfolio
# 5               https://example.com/flutter-portfolio
# 6             https://example.com/wordpress-portfolio
# 7               https://example.com/magento-portfolio
# 8          https://example.com/react-native-portfolio
# 9                   https://example.com/ios-portfolio
# 10              https://example.com/android-portfolio
# 11       https://example.com/kotlin-android-portfolio
# 12           https://example.com/android-tv-portfolio
# 13               https://example.com/ios-ar-portfolio
# 14              https://example.com/xamarin-portfolio
# 15       https://example.com/kotlin-backend-portfolio
# 16  https://example.com/typescript-frontend-portfolio
# 17        https://example.com/full-stack-js-portfolio
# 18            https://example.com/ml-python-portfolio
# 19               https://example.com/devops-portfolio

# %%
import uuid
import chromadb

client = chromadb.PersistentClient('vectorstore')
collection = client.get_or_create_collection(name="portfolio")

if not collection.count():
    for _, row in df.iterrows():
        collection.add(documents=row["Techstack"],
                       metadatas={"links": row["Links"]},
                       ids=[str(uuid.uuid4())])

# %%
links = collection.query(query_texts=job['skills'], n_results=2).get('metadatas', [])
links
# Out:
# [[{'links': 'https://example.com/android-tv-portfolio'},
#   {'links': 'https://example.com/kotlin-backend-portfolio'}]]

# %%
job = json_res[0]

job['skills']
# Out:
# ''

# %%
prompt_email = PromptTemplate.from_template(
        """
        ### JOB DESCRIPTION:
        {job_description}
        
        ### INSTRUCTION:
        You are Mohan, a business development executive at AtliQ. AtliQ is an AI & Software Consulting company dedicated to facilitating
        the seamless integration of business processes through automated tools. 
        Over our experience, we have empowered numerous enterprises with tailored solutions, fostering scalability, 
        process optimization, cost reduction, and heightened overall efficiency. 
        Your job is to write a cold email to the client regarding the job mentioned above describing the capability of AtliQ 
        in fulfilling their needs.
        Also add the most relevant ones from the following links to showcase Atliq's portfolio: {link_list}
        Remember you are Mohan, BDE at AtliQ. 
        Do not provide a preamble.
        ### EMAIL (NO PREAMBLE):
        
        """
        )

chain_email = prompt_email | llm
res = chain_email.invoke({"job_description": str(job), "link_list": links})
print(res.content)
# Out:
# Subject: Enhancing Operational Efficiency for Kaufmann/-frau im Einzelhandel (Ausbildung) Role
#
# Dear Hiring Manager,
#
# I came across the job posting for Kaufmann/-frau im Einzelhandel (Ausbildung) at your esteemed organization, and I am excited to introduce AtliQ, an AI & Software Consulting company that can help streamline your business processes. With our expertise in automation, we can assist in optimizing the operational efficiency of your retail operations, particularly for the 37.5 hours/week role in Metzingen.
#
# At AtliQ, we have a proven track record of empowering enterprises with tailored solutions, resulting in scalability, process optimization, cost reduction, and heightened overall efficiency. Our team of experts can help design and implement automated tools to support the Kaufmann/-frau im Einzelhandel (Ausbildung) role, ensuring seamless integration of business processes.
#
# I would like to highlight some of our notable projects that demonstrate our capabilities:
# - Our work on Android TV solutions (https://example.com/android-tv-portfolio) showcases our ability to develop innovative and user-friendly interfaces, which can be applied to enhance the customer experience in retail settings.
# - Our expertise in Kotlin backend development (https://example.com/kotlin-backend-portfolio) can help build robust and scalable backend systems to support your retail operations, ensuring efficient data management and processing.
#
# By partnering with AtliQ, you can leverage our technical expertise to enhance the productivity and efficiency of your Kaufmann/-frau im Einzelhandel (Ausbildung) role. I would be delighted to schedule a call to discuss how our solutions can address your specific needs and challenges.
#
# Please feel free to contact me at your convenience. I look forward to the opportunity to collaborate and drive business growth for your organization.
#
# Best regards,
#
# Mohan
# Business Development Executive
# AtliQ
